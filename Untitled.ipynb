# %%
import pandas as pd

# %%
data = pd.read_csv('Fifa_world_cup_matches.csv')
data
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
df_new = data.assign(new_col=range(1, len(df) + 1))
df_new
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
print("Number of rows: ", df.shape[0])
print("Number of columns: ", df.shape[1])
print("Features:", df.columns.tolist())
print("\n Missing values: ", df.isnull().sum().values)
print("Data types:", df.dtypes)
print("Sample data:", df.head())



max_value_column = df["possession team1"].max()
max_value_column

# row = df.loc[df['possession team1'] == max_value_column['team 1']]
# row

# print("Team with the most possession was" df.loc[df['possession team1'] == max_value_column['team 1'].item() " and played against" + "on" + )
# Out:
# Number of rows:  64
# Number of columns:  88
# ...

# %%
from collections import Counter


c = Counter()
for words in df['category']:
    c.update(words)
common_words = [word for word, count in c.items() if count == df.shape[0]]
df_new = df.assign(common_words=common_words)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-40dce4aa172c> in <module>
#      12 if __name__ == '__main__':
#      13     df = pd.read_csv('Fifa_world_cup_matches.csv')
# ---> 14     df_new = separate_common_elements(df)
#      15     print(df_new)
#
# <ipython-input-40-40dce4aa172c> in separate_common_elements(df)
#       7         c.update(words)
#       8     common_words = [word for word, count in c.items() if count == df.shape[0]]
# ----> 9     df_new = df.assign(common_words=common_words)
#      10     return df_new
#      11
#
# D:\ana\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    3828
#    3829         for k, v in kwargs.items():
# -> 3830             data[k] = com.apply_if_callable(v, data)
#    3831         return data
#    3832
#
# D:\ana\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
# ...
